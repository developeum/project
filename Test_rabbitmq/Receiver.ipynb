# %%
import pika
import json
import pandas as pd

# %%
connection = pika.BlockingConnection(pika.ConnectionParameters('localhost'))
channel = connection.channel()

# %%
channel.queue_declare(queue='my_queue')
# Out:
# <METHOD(['channel_number=1', 'frame_type=1', "method=<Queue.DeclareOk(['consumer_count=0', 'message_count=0', 'queue=my_queue'])>"])>

# %%
def callback(ch, method, properties, body):
    print(" [x] Received data")
    data = body.decode('utf8')
    new_data = json.loads(data)
    events_df = pd.DataFrame(new_data)

# %%
channel.basic_consume(queue='my_queue',
                      auto_ack=True,
                      on_message_callback=callback)
# Out:
# 'ctag1.19c0a5d1a32c4b53bfcc2cf472652b40'

# %%
print(' [*] Waiting for messages. To exit interrupt the kernel')
channel.start_consuming()
# Out:
#  [*] Waiting for messages. To exit interrupt the kernel
#  [x] Received data
# b'[{"categories": ["BA", "\\u043a\\u0443\\u0440\\u0441\\u044b"], "event_time": "2020-08-17 21:00:00+00", "event_type": "\\u0422\\u0440\\u0435\\u043d\\u0438\\u043d\\u0433", "name": "16-\\u0439 \\u043a\\u0443\\u0440\\u0441 BASpace \\"\\u041e\\u0441\\u043d\\u043e\\u0432\\u044b \\u0431\\u0438\\u0437\\u043d\\u0435\\u0441-\\u0430\\u043d\\u0430\\u043b\\u0438\\u0437\\u0430\\"", "description": "\\u041e\\u0442\\u043a\\u0440\\u044b\\u0442 \\u043d\\u0430\\u0431\\u043e\\u0440 \\u043d\\u0430 16-\\u0439 online-\\u043a\\u0443\\u0440\\u0441 BASpace \\"\\u041e\\u0441\\u043d\\u043e\\u0432\\u044b \\u0431\\u0438\\u0437\\u043d\\u0435\\u0441-\\u0430\\u043d\\u0430\\u043b\\u0438\\u0437\\u0430\\" \\u0421\\u0442\\u0430\\u0440\\u0442: 18 \\u0430\\u0432\\u0433\\u0443\\u0441\\u0442\\u0430 (\\u0432\\u0442.) \\u0432 19:00 \\u0424\\u043e\\u0440\\u043c\\u0430\\u0442: Online \\u0420\\u0430\\u0441\\u043f\\u0438\\u0441\\u0430\\u043d\\u0438\\u0435: \\u0432\\u0442\\u043e\\u0440\\u043d\\u0438\\u043a \\u0438 \\u0447\\u0435\\u0442\\u0432\\u0435\\u0440\\u0433 \\u0441 18:30/19.00 \\u0434\\u043e 21.00/21.30 \\u0421\\u0442\\u043e\\u0438\\u043c\\u043e\\u0441\\u0442\\u044c (\\u0432 \\u0437\\u0430\\u0432\\u0438\\u0441\\u0438\\u043c\\u043e\\u0441\\u0442\\u0438 \\u043e\\u0442 \\u041f\\u0430\\u043a\\u0435\\u0442\\u0430 ): \\u043e\\u0442 335$ \\u0432 \\u0433\\u0440\\u043d. \\u044d\\u043a\\u0432. (\\u043e\\u043f\\u043b\\u0430\\u0447\\u0438\\u0432\\u0430\\u0442\\u044c \\u0432\\u043e\\u0437\\u043c\\u043e\\u0436\\u043d\\u043e \\u043f\\u043e\\u044d\\u0442\\u0430\\u043f\\u043d\\u043e) \\u0421\\u043a\\u0438\\u0434\\u043a\\u0430: \\u0441\\u043a\\u0438\\u0434\\u043a\\u0430 \\u2014 999 \\u0433\\u0440\\u043d. \\u043f\\u043e \\u043f\\u0440\\u043e\\u043c\\u043e\\u043a\\u043e\\u0434\\u0443 DOU \\u043f\\u0440\\u0438 \\u0440\\u0435\\u0433\\u0438\\u0441\\u0442\\u0440\\
# [{'categories': ['BA', 'курсы'], 'event_time': '2020-08-17 21:00:00+00', 'event_type': 'Тренинг', 'name': '16-й курс BASpace "Основы бизнес-анализа"', 'description': 'Открыт набор на 16-й online-курс BASpace "Основы бизнес-анализа" Старт: 18 августа (вт.) в 19:00 Формат: Online Расписание: вторник и четверг с 18:30/19.00 до 21.00/21.30 Стоимость (в зависимости от Пакета ): от 335$ в грн. экв. (оплачивать возможно поэтапно) Скидка: скидка — 999 грн. по промокоду DOU при регистрации и оплате до 10.08.2020 Длительность: 2,5 месяца / >41 час, получаете записи Подробности и регистрация: new.ba-space.org К нам приходят после других курсов по бизнес-анализу и Product Ownership не просто так :). Самая полная программа, внимательные тренеры-практики с огромным опытом (один из них — бывший программист), минимум воды, максимум полезного материала и практики . При выборе любого курса, обязательно изучите программу , прочитайте о том, кто тренеры, поищите отзывы о нас и убедитесь сами. Также, можно записаться на отдельные online модули /появился новый модуль по Product Ownership/. Наши курсы продаются в основном через "сарафанное радио", потому что качество продукта говорит само за себя. Регистрируйтесь сейчас , группа маленькая, скоро закроем набор. Для кого : 1/ для тех, кто только планирует стартовать свою карьеру в IT 2/ для тех, кто уже в IT. Кто проходил наш курс и уже получил пользу в работе либо сменил направление деятельности: бизнес аналитики, Project Manager-ы, QA Engineers, Product Owners, разработчики, СЕО и СОО маленькой компании, который "сам себе режиссёр", Account Managers, HRs, CSs, все остальные, кто работает с заказчиками и/или с командами на тему требований или бизнес-процессов либо те, кто строит бизнес-процессы в компаниях под запрос. О роли бизнес-аналитика: В IT-компаниях роль бизнес-аналитика существует всегда, это может быть не выделенная должность, иногда ее выполняет лидер ( Project Manager, Product Owner, Account Manager, TL и пр. ) либо член команды ( тестировщик, разработчик ) либо компания настолько продвинутая, что у нее есть Business Analyst либо Product Owner как выделенная должность. Бизнес аналитик — это не технический писатель, как принято в некоторых IT-бизнесах, он общается с Заказчиком, разбирается в его предметной области, его бизнес-процессах и ценности этих процессов (value), а также, знает возможности компании либо продукта (например, разбирается в функционале продукта, если это продукт, понимает его сферу бизнеса, консультирует Заказчика, чтобы получить идеальный match). Он общается с Заказчиком, понимая его бизнес, его "боль". Поверьте, иногда задав нужные вопросы Заказчику в нужный момент, вы сэкономите нервы, деньги, а ещё и приобретете лояльность либо даже дружбу Заказчика, т.к он сам для себя поймет фокус собственного бизнеса, а иногда даже изменит / продумает модель монетизации. Также бизнес-аналитик преобразовывает это все в документацию и требования для команды, отрисует мокапы, опишет user story и т.п. Этому всему и учимся. О курсе: На курсе мы изучаем все инструменты, которые позволят вам быть профессионалом в бизнес-анализе, например — интервью с заказчиком, customer path, story map, работу с персонами (Personas), use case diagram & сценарии, UML диаграммы, BPMN диаграммы и прочее, что поможет в работе с процессами и требованиями (смотри Программу ). Те же самые инструменты актуальны и для себя — применительно к своим личным идеям/проектам либо для оптимизации собственного бизнеса и бизнес-процессов. Не упустите этой возможности — группа маленькая, будут домашки, много практики, обмен опытом, дружеская атмосфера. Подход глубже, чем обычно на курсах, т.к. Николай Шемшур — ведущий бизнес-аналитик и руководитель отдела бизнес-анализа и процессов, также опытный программист в прошлом. У Николая есть опыт работы с самыми разными бизнесами и Заказчиками, и бесконечное терпение, доброта и профессионализм для проверки домашек и ответы на ВСЕ ваши вопросы ;). Другие тренеры — тоже профи своег ...
# <class 'pandas.core.frame.DataFrame'>
#                                           categories              event_time  \
# 0                                        [BA, курсы]  2020-08-17 21:00:00+00
# 1                                                 []  2020-05-20 21:00:00+00
# 2                                                 []  2020-07-30 21:00:00+00
# 3                                   [вебинар, cloud]  2020-06-23 21:00:00+00
# 4                                 [курсы, маркетинг]  2020-06-23 21:00:00+00
# 5                                                 []  2020-05-29 21:00:00+00
# 6                                                 []  2020-06-14 21:00:00+00
# 7                         [семинар, стартап, бизнес]  2020-07-01 21:00:00+00
# 8                                                 []  2020-05-28 21:00:00+00
# 9  [аудитсайта, палий, аудитсайта, палий, вебинар...  2020-08-05 21:00:00+00
#
#   event_type                                               name  \
# 0    Тренинг          16-й курс BASpace "Основы бизнес-анализа"
# 1      Митап                             1Ci Partner day Warsaw
# 2      Митап              2020 Call for Code - Global Challenge
# 3      Митап              24hrs of Google Cloud Talks by DevRel
# 4      Митап  2-х тижневий інтенсив Marketing school від STU...
# 5      Митап                          3-й виртуальный PHP-митап
# 6    Вебинар             3 кита эффективной контекстной рекламы
# 7      Митап   42 Investment Summit 2020: Matchmaking from Home
# 8    Вебинар  5 шагов составления семантики для контекстной ...
# 9    Вебинар  60 минут Аудита сайта Онлайн: в гостях Иван Па...
#
#                                          description  id      city
# 0  Открыт набор на 16-й online-курс BASpace "Осно...   0  Интернет
# 1  1Ci Partner's day Warsaw Организатор: 1C Inter...   1    Москва
# 2  This meetup is listed as July 31st which is th...   2    Москва
# 3  This event for enterprise practitioners, devel...   3  Интернет
# 4  Marketing school від STUD-POINT — 2-х тижневий...   4  Интернет
# 5  В субботу, 30 мая, с 11 утра пройдёт 3-й вирту...   5    Москва
# 6  15 июня с 14:00 до 15:00 по Мск пройдет беспла...   6  Интернет
# 7  The two-day international online conference 42...   7  Интернет
# 8  Бесплатный вебинар для всех, кто уже ведет или...   8  Интернет
# 9  6 августа в 15:00 мы проведем вебинар на тему ...   9  Интернет
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a24ab7540327> in <module>
#       1 print(' [*] Waiting for messages. To exit interrupt the kernel')
# ----> 2 channel.start_consuming()
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in start_consuming(self)
#    1864         while self._consumer_infos:
#    1865             # This will raise ChannelClosed if channel is closed by broker
# -> 1866             self._process_data_events(time_limit=None)
#    1867
#    1868     def stop_consuming(self, consumer_tag=None):
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in _process_data_events(self, time_limit)
#    2025
#    2026         """
# -> 2027         self.connection.process_data_events(time_limit=time_limit)
#    2028         if self.is_closed and isinstance(self._closing_reason,
#    2029                                          exceptions.ChannelClosedByBroker):
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in process_data_events(self, time_limit)
#     823                                               self._ready_events))
#     824             if time_limit is None:
# --> 825                 self._flush_output(common_terminator)
#     826             else:
#     827                 with _IoloopTimerContext(time_limit, self._impl) as timer:
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/blocking_connection.py in _flush_output(self, *waiters)
#     511         # Process I/O until our completion condition is satisfied
#     512         while not is_done():
# --> 513             self._impl.ioloop.poll()
#     514             self._impl.ioloop.process_timeouts()
#     515
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/select_connection.py in poll(self)
#     574
#     575         """
# --> 576         self._poller.poll()
#     577
#     578
#
# ~/.local/lib/python3.8/site-packages/pika/adapters/select_connection.py in poll(self)
#    1179         while True:
#    1180             try:
# -> 1181                 events = self._poll.poll(self._get_max_wait())
#    1182                 break
#    1183             except _SELECT_ERRORS as error:
#
# KeyboardInterrupt:
